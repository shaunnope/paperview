# %%
import pandas as pd

df = pd.read_csv("straitstimes_20220104_20231107.csv")
df['content'] = df['article'].str.lower()

for i in range(30):
    df[f"rel_{i}"] = 0.0

# %%
def contains(df: pd.DataFrame, word, col='content'):
    return df[col].str.contains(word)

# %%
# Who is the Prime Minister of Singapore?
print(0, df.loc[contains(df, 'prime minister'), 'rel_0'].shape)
df.loc[contains(df, 'prime minister'), 'rel_0'] = 0.2
df.loc[contains(df, 'prime minister') & contains(df, 'lee kuan yew'), 'rel_0'] = 0.4
df.loc[contains(df, 'prime minister') & ~contains(df, 'lee hsien loong'), 'rel_0'] = 0.4
df.loc[contains(df, 'prime minister') & contains(df, 'lawrence wong'), 'rel_0'] = 0.6
df.loc[contains(df, 'prime minister') & contains(df, 'chan chun sing'), 'rel_0'] = 0.5
df.loc[contains(df, 'prime minister') & contains(df, 'lee hsien loong'), 'rel_0'] = 1.0

# What is the top university in Singapore?
print(1, df.loc[contains(df, 'university'), 'rel_1'].shape)
df.loc[contains(df, 'university'), 'rel_1'] = 0.1
df.loc[contains(df, 'university') & contains(df, 'nanyang technological university'), 'rel_1'] = 0.6
df.loc[contains(df, 'university') & contains(df, 'singapore management university'), 'rel_1'] = 0.6
df.loc[contains(df, 'university') & contains(df, 'singapore university of'), 'rel_1'] = 0.6
df.loc[contains(df, 'university') & contains(df, 'singapore institute'), 'rel_1'] = 0.6
df.loc[contains(df, 'university') & contains(df, 'national university of singapore'), 'rel_1'] = 1.0

# What's the climate like in Singapore this time of year?
print(2, df.loc[contains(df, 'climate'), 'rel_2'].shape)
df.loc[contains(df, 'climate') | contains(df, 'weather'), 'rel_2'] = 0.1
df.loc[contains(df, 'climate') | contains(df, 'weather') & contains(df, 'humid'), 'rel_2'] = 0.8
df.loc[contains(df, 'climate') | contains(df, 'weather') & contains(df, 'hot'), 'rel_2'] = 0.8

# How does scamming affect victims' mental health in Singapore?
print(3, df.loc[contains(df, 'scam'), 'rel_3'].shape)
df.loc[contains(df, 'scam') | contains(df, 'mental'), 'rel_3'] = 0.1
df.loc[contains(df, 'scam') & contains(df, 'mental') & contains(df, 'fraud'), 'rel_3'] = 0.8
df.loc[contains(df, 'scam') & contains(df, 'mental') & contains(df, 'fraud') & contains(df, 'victim'), 'rel_3'] = 1.0

# How did Singapore fare against Japan in the recent badminton championship?
print(4, df.loc[contains(df, 'badminton'), 'rel_4'].shape)
df.loc[contains(df, 'badminton') | contains(df, 'japan') | contains(df, 'champion'), 'rel_4'] = 0.2
df.loc[contains(df, 'badminton') & contains(df, 'japan') & contains(df, 'champion'), 'rel_4'] = 1.0

# What's the new scheme for Covid-19 swabs in Singapore?
print(5, df.loc[contains(df, 'covid') | contains(df, 'swab'), 'rel_5'].shape)
df.loc[contains(df, 'covid') | contains(df, 'swab'), 'rel_5'] = 0.1
df.loc[contains(df, 'covid') & contains(df, 'swab'), 'rel_5'] = 1.0

# What decision did President Halimah Yacob make regarding two drug traffickers?
print(6, df.loc[contains(df, 'president') | contains(df, 'trafficker'), 'rel_6'].shape)
df.loc[contains(df, 'budget'), 'rel_6'] = 0.1
df.loc[contains(df, 'budget') & contains(df, 'post-pandemic'), 'rel_6'] = 1.0

# What decision did President Halimah Yacob make regarding two drug traffickers?
print(7, df.loc[contains(df, 'president') | contains(df, 'trafficker'), 'rel_7'].shape)
df.loc[contains(df, 'president') | contains(df, 'trafficker'), 'rel_7'] = 0.1
df.loc[contains(df, 'president') & contains(df, 'trafficker'), 'rel_7'] = 1.0

# What's the status of press freedom in Singapore?
print(8, df.loc[contains(df, 'press') | contains(df, 'freedom'), 'rel_8'].shape)
df.loc[contains(df, 'press') | contains(df, 'freedom'), 'rel_8'] = 0.1
df.loc[contains(df, 'press') & contains(df, 'freedom'), 'rel_8'] = 1.0

# What happened in the police confrontation at Clementi?
print(9, df.loc[contains(df, 'clementi') | contains(df, 'police'), 'rel_9'].shape)
df.loc[contains(df, 'clementi') | contains(df, 'police'), 'rel_9'] = 0.1
df.loc[contains(df, 'clementi') & contains(df, 'police'), 'rel_9'] = 0.8
df.loc[contains(df, 'clementi') & contains(df, 'police') & contains(df, 'controntation'), 'rel_9'] = 1.0

# What are the key takeaways from the recent Singapore Airshow?
print(10, df.loc[contains(df, 'airshow') | contains(df, 'aircraft'), 'rel_10'].shape)
df.loc[contains(df, 'airshow') | contains(df, 'aircraft'), 'rel_10'] = 0.1
df.loc[contains(df, 'airshow') & contains(df, 'aircraft'), 'rel_10'] = 0.8
df.loc[contains(df, 'airshow') & contains(df, 'taxi'), 'rel_10'] = 1.0

# What major tax measures were introduced in Singapore's Budget 2022?
print(11, df.loc[contains(df, 'budget') | contains(df, 'tax'), 'rel_11'].shape)
df.loc[contains(df, 'budget') | contains(df, 'tax'), 'rel_11'] = 0.1
df.loc[contains(df, 'budget') & contains(df, 'tax'), 'rel_11'] = 0.8

# What are the updates on the twin murder case in Upper Bukit Timah?
print(12, df.loc[contains(df, 'twin') | contains(df, 'murder'), 'rel_12'].shape)
df.loc[contains(df, 'twin') | contains(df, 'murder'), 'rel_12'] = 0.1
df.loc[contains(df, 'twin') & contains(df, 'murder'), 'rel_12'] = 1.0

# What is Singapore's approach to handling the climate crisis as per Budget 2022?
print(13, df.loc[contains(df, 'budget') | contains(df, 'climate'), 'rel_13'].shape)
df.loc[contains(df, 'budget') | contains(df, 'climate'), 'rel_13'] = 0.1
df.loc[contains(df, 'budget') & contains(df, 'climate'), 'rel_13'] = 0.8

# What is the goal of the Citizen Archivist initiative in Singapore?
print(14, df.loc[contains(df, 'citizen') | contains(df, 'archivist'), 'rel_14'].shape)
df.loc[contains(df, 'citizen') | contains(df, 'archivist'), 'rel_14'] = 0.1
df.loc[contains(df, 'citizen') & contains(df, 'archivist'), 'rel_14'] = 1.0

# How did China's economic performance impact Singapore's stock market?
print(15, df.loc[contains(df, 'china') | contains(df, 'stock'), 'rel_15'].shape)
df.loc[contains(df, 'china') | contains(df, 'stock'), 'rel_15'] = 0.1
df.loc[contains(df, 'china') & contains(df, 'stock'), 'rel_15'] = 0.8

# What is the controversy surrounding the Red Lions name in Singapore?
print(16, df.loc[contains(df, 'red lion') | contains(df, 'name'), 'rel_16'].shape)
df.loc[contains(df, 'red lion') | contains(df, 'name'), 'rel_16'] = 0.1
df.loc[contains(df, 'red lion') & contains(df, 'name'), 'rel_16'] = 0.8
df.loc[contains(df, 'red lion') & contains(df, 'group'), 'rel_16'] = 1.0

# How is Lee Kuan Yew remembered in Singapore?
print(17, df.loc[contains(df, 'lee kuan yew') | contains(df, 'remember'), 'rel_17'].shape)
df.loc[contains(df, 'lee kuan yew') | contains(df, 'remember'), 'rel_17'] = 0.1
df.loc[contains(df, 'lee kuan yew') & contains(df, 'remember'), 'rel_17'] = 1.0

# How has Singapore's stock market reacted to global economic trends recently?
print(18, df.loc[contains(df, 'stock') | contains(df, 'market'), 'rel_18'].shape)
df.loc[contains(df, 'stock') | contains(df, 'market'), 'rel_18'] = 0.1
df.loc[contains(df, 'stock') & contains(df, 'market'), 'rel_18'] = 0.8
df.loc[contains(df, 'stock') & contains(df, 'market') & contains(df, 'global'), 'rel_18'] = 1.0

# What measures are being taken in Singapore as the dengue peak season approaches?
print(19, df.loc[contains(df, 'dengue') | contains(df, 'peak'), 'rel_19'].shape)
df.loc[contains(df, 'dengue') | contains(df, 'peak'), 'rel_19'] = 0.1
df.loc[contains(df, 'dengue') & contains(df, 'peak'), 'rel_19'] = 0.8
df.loc[contains(df, 'dengue') & contains(df, 'peak') & contains(df, 'measure'), 'rel_19'] = 1.0

# What is the new themed zone planned for Universal Studios Singapore in 2024, and which attraction will it replace?
print(20, df.loc[contains(df, 'universal studios'), 'rel_20'].shape)
df.loc[contains(df, 'universal studios'), 'rel_20'] = 0.1
df.loc[contains(df, 'universal studios') & contains(df, '2024'), 'rel_20'] = 1.0

# What is the purpose of the recent property tax increase in Singapore as per the ST-UOB panel discussion?
print(21, df.loc[contains(df, 'property tax'), 'rel_21'].shape)
df.loc[contains(df, 'property tax'), 'rel_21'] = 0.1
df.loc[contains(df, 'property tax') & contains(df, 'panel'), 'rel_21'] = 0.8

# How many people have been arrested and charged in connection with the OCBC phishing scams?
print(22, df.loc[contains(df, 'ocbc') | contains(df, 'phishing'), 'rel_22'].shape)
df.loc[contains(df, 'ocbc') | contains(df, 'phishing'), 'rel_22'] = 0.1
df.loc[contains(df, 'ocbc') & contains(df, 'phishing'), 'rel_22'] = 0.8
df.loc[contains(df, 'ocbc') & contains(df, 'arrest'), 'rel_22'] = 1.0

# ow might the carbon tax hike affect the cost of living for Singaporean households, despite utility rebates?
print(23, df.loc[contains(df, 'carbon tax') | contains(df, 'cost of living'), 'rel_23'].shape)
df.loc[contains(df, 'carbon tax') | contains(df, 'cost of living'), 'rel_23'] = 0.1
df.loc[contains(df, 'carbon tax') & contains(df, 'cost of living'), 'rel_23'] = 0.8

# What do fully vaccinated travelers need to know about Singapore's new border measures?
print(24, df.loc[contains(df, 'border') | contains(df, 'travel'), 'rel_24'].shape)
df.loc[contains(df, 'border') | contains(df, 'travel'), 'rel_24'] = 0.1
df.loc[contains(df, 'border') & contains(df, 'travel'), 'rel_24'] = 0.8
df.loc[contains(df, 'border') & contains(df, 'travel') & contains(df, 'vaccinated'), 'rel_24'] = 1.0

# Which sectors could see potential wins and losses from Singapore's 2022 Budget?
print(25, df.loc[contains(df, 'budget') | contains(df, 'sector'), 'rel_25'].shape)
df.loc[contains(df, 'budget') | contains(df, 'sector'), 'rel_25'] = 0.1
df.loc[contains(df, 'budget') & contains(df, 'sector'), 'rel_25'] = 0.8
df.loc[contains(df, 'budget') & contains(df, 'sector') & contains(df, 'loss'), 'rel_25'] = 1.0

# Has public transport ridership in Singapore returned to pre-pandemic levels?
print(26, df.loc[contains(df, 'transport') | contains(df, 'ridership'), 'rel_26'].shape)
df.loc[contains(df, 'transport') | contains(df, 'ridership'), 'rel_26'] = 0.1
df.loc[contains(df, 'transport') & contains(df, 'ridership'), 'rel_26'] = 1.0

# What service allows Singaporeans to receive government payouts from ATMs?
print(27, df.loc[contains(df, 'atm') | contains(df, 'payout'), 'rel_27'].shape)
df.loc[contains(df, 'atm') | contains(df, 'payout'), 'rel_27'] = 0.1
df.loc[contains(df, 'atm') & contains(df, 'payout'), 'rel_27'] = 1.0

# How has the attendance at the Pink Dot event changed since it first started?
print(28, df.loc[contains(df, 'pink dot') | contains(df, 'attendance'), 'rel_28'].shape)
df.loc[contains(df, 'pink dot'), 'rel_28'] = 0.1
df.loc[contains(df, 'pink dot') & contains(df, 'attendance'), 'rel_28'] = 1.0
# Out:
# 0 (185,)
# 1 (239,)
# 2 (105,)
# 3 (115,)
# 4 (26,)
# 5 (535,)
# 6 (283,)
# 7 (283,)
# 8 (365,)
# 9 (325,)
# 10 (40,)
# 11 (207,)
# 12 (31,)
# 13 (205,)
# 14 (109,)
# 15 (219,)
# 16 (289,)
# 17 (82,)
# 18 (372,)
# 19 (384,)
# 20 (5,)
# 21 (14,)
# 22 (83,)
# 23 (36,)
# 24 (280,)
# 25 (332,)
# 26 (163,)
# 27 (175,)
# 28 (25,)

# %%
# create new df with columns 'article_id', 'question_id', 'relevance'
rel_rows = []
for idx, row in df.iterrows():
    for i in range(30):
        if row[f'rel_{i}'] > 0:
            rel_rows.append({'article_id': idx, 'question_id': i, 'relevance': row[f'rel_{i}']})

rel_df = pd.DataFrame(rel_rows)
rel_df.to_csv('relevance.csv', index=False)
